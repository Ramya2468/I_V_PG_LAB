# %%
import cv2
import matplotlib.pyplot as plt

# Specify the path to the image file
image_path = r"C:\Users\ramco\OneDrive\Desktop\Mtech Docs\Second Sem\Image and Video\PG_lab\Photo1.jpg"

# Load the image in BGR format (OpenCV default)
image_bgr = cv2.imread(image_path)

# Check if the image was loaded successfully
if image_bgr is None:
    raise ValueError("Image not loaded. Check the file path and format.")

# Save the modified RGB image to a new file
saved_image_path = r"C:\Users\ramco\OneDrive\Desktop\Mtech Docs\Second Sem\Image and Video\PG_lab\Photo2.jpg"
cv2.imwrite(saved_image_path, cv2.cvtColor(image_rgb, cv2.COLOR_RGB2BGR))  # Convert back to BGR for saving


# Convert the BGR image to RGB format
image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)

# Convert the RGB image to grayscale
image_gray = cv2.cvtColor(image_rgb, cv2.COLOR_RGB2GRAY)

# Display the original RGB image and the grayscale image inline
plt.figure(figsize=(15, 5))

# Display the original RGB image
plt.subplot(1, 2, 1)
plt.imshow(image_rgb)
plt.title('Original RGB Image')
plt.axis('off')

# Display the grayscale image
plt.subplot(1, 2, 2)
plt.imshow(image_gray, cmap='gray')
plt.title('Grayscale Image')
plt.axis('off')

plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

# Load the image in BGR format (OpenCV default)
image_bgr = cv2.imread(image_path)

# Check if the image was loaded successfully
if image_bgr is None:
    raise ValueError("Image not loaded. Check the file path and format.")

# Convert the BGR image to RGB format
image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)

# Get the dimensions of the image
height, width, _ = image_rgb.shape

# Compute the coordinates of the center pixel
center_y, center_x = height // 2, width // 2

# Define the size of the block to change (e.g., a fraction of the image dimensions)
block_height = height // 30  # Change to a fraction of the height
block_width = width // 30  # Change to a fraction of the width

# Ensure the block size is odd to center the change on the exact pixel
block_height = block_height if block_height % 2 == 1 else block_height + 1
block_width = block_width if block_width % 2 == 1 else block_width + 1

# Define the block of pixels around the center
start_y = max(center_y - block_height // 2, 0)
end_y = min(center_y + block_height // 2 + 1, height)
start_x = max(center_x - block_width // 2, 0)
end_x = min(center_x + block_width // 2 + 1, width)

# Change a block of pixels around the center pixel to red (255, 0, 0)
image_rgb[start_y:end_y, start_x:end_x] = [255, 0, 0]  # Red

# Save the modified RGB image to a new file
saved_image_path = r"C:\Users\ramco\OneDrive\Desktop\Mtech Docs\Second Sem\Image and Video\PG_lab\Photo2.jpg"
cv2.imwrite(saved_image_path, cv2.cvtColor(image_rgb, cv2.COLOR_RGB2BGR))  # Convert back to BGR for saving

# Display the modified RGB image
plt.figure(figsize=(7.5, 5))
plt.imshow(image_rgb)
plt.title('Modified RGB Image with Center Pixel Block Changed')
plt.axis('off')
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

# Load the image in BGR format (OpenCV default)
image_bgr = cv2.imread(image_path)

# Check if the image was loaded successfully
if image_bgr is None:
    raise ValueError("Image not loaded. Check the file path and format.")

# Convert the BGR image to RGB format
image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)

# Define the size of the block to change
block_size = 20

# Define the block of pixels in the top-left corner
start_y, start_x = 0, 0
end_y = min(start_y + block_size, image_rgb.shape[0])
end_x = min(start_x + block_size, image_rgb.shape[1])

# Change the 20x20 block of pixels in the top-left corner to blue (0, 0, 255)
image_rgb[start_y:end_y, start_x:end_x] = [0, 0, 255]  # Blue

# Save the modified RGB image to a new file
original_image_path = r"C:\Users\ramco\OneDrive\Desktop\Mtech Docs\Second Sem\Image and Video\PG_lab\Photo1 - Copy.jpg"
cv2.imwrite(original_image_path, cv2.cvtColor(image_rgb, cv2.COLOR_RGB2BGR))  # Convert back to BGR for saving

# Display the modified RGB image
plt.figure(figsize=(7.5, 5))
plt.imshow(image_rgb)
plt.title('Modified RGB Image with Top-Left Corner Block Changed to Blue')
plt.axis('off')
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

# Specify the path to the image file
image_path = r"C:\Users\ramco\OneDrive\Desktop\Mtech Docs\Second Sem\Image and Video\PG_lab\Photo1.jpg"

# Load the image in BGR format (OpenCV default)
image_bgr = cv2.imread(image_path)

# Check if the image was loaded successfully
if image_bgr is None:
    raise ValueError("Image not loaded. Check the file path and format.")

# Convert the BGR image to RGB format
image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)

# Define the text to add
text = "I am proud to be an Indian"

# Define text properties
font = cv2.FONT_HERSHEY_SIMPLEX
font_scale = 7
font_color = (0, 0, 255)  # Red color in RGB
thickness = 10
line_type = cv2.LINE_AA

# Get text size to position the text properly
(text_width, text_height), baseline = cv2.getTextSize(text, font, font_scale, thickness)
height, width, _ = image_rgb.shape

# Calculate the position for centered text
text_x = (width - text_width) // 2
text_y = (height + text_height) // 2

# Add text to the image
cv2.putText(image_rgb, text, (text_x, text_y), font, font_scale, font_color, thickness, line_type)

# Save the modified RGB image to a new file
saved_image_path = r"C:\Users\ramco\OneDrive\Desktop\Mtech Docs\Second Sem\Image and Video\PG_lab\Photo1 - Copy.jpg"
cv2.imwrite(saved_image_path, cv2.cvtColor(image_rgb, cv2.COLOR_RGB2BGR))  # Convert back to BGR for saving

# Display the modified RGB image with text
plt.figure(figsize=(7.5, 5))
plt.imshow(image_rgb)
plt.title('Modified RGB Image with Centered Text')
plt.axis('off')
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

# Specify the path to the image file
image_path = r"C:\Users\ramco\OneDrive\Desktop\Mtech Docs\Second Sem\Image and Video\PG_lab\Photo1.jpg"

# Load the image in BGR format (OpenCV default)
image_bgr = cv2.imread(image_path)

# Check if the image was loaded successfully
if image_bgr is None:
    raise ValueError("Image not loaded. Check the file path and format.")

# Convert the BGR image to RGB format
image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)

# Define the text to add
text = "I am proud to be an Indian"

# Define text properties
font = cv2.FONT_HERSHEY_SIMPLEX
font_scale = 3.5
font_color = (0, 0, 255)  # White color in RGB
thickness = 3
line_type = cv2.LINE_AA

# Get text size to position the text properly
(text_width, text_height), baseline = cv2.getTextSize(text, font, font_scale, thickness)
height, width, _ = image_rgb.shape

# Define circle properties
center_x, center_y = width // 2, height // 2
radius = 800

# Draw the circle on the image
cv2.circle(image_rgb, (center_x, center_y), radius, (0, 255, 0), 7)  # Green circle with thickness of 5

# Calculate the position for centered text inside the circle
text_x = center_x - text_width // 2
text_y = center_y + text_height // 2

# Add text inside the circle
cv2.putText(image_rgb, text, (text_x, text_y), font, font_scale, font_color, thickness, line_type)

# Save the modified RGB image to a new file
saved_image_path = r"C:\Users\ramco\OneDrive\Desktop\Mtech Docs\Second Sem\Image and Video\PG_lab\Photo1 - Copy with Circle.jpg"
cv2.imwrite(saved_image_path, cv2.cvtColor(image_rgb, cv2.COLOR_RGB2BGR))  # Convert back to BGR for saving

# Display the modified RGB image with circle and text
plt.figure(figsize=(7.5, 5))
plt.imshow(image_rgb)
plt.title('Modified RGB Image with Circle and Text')
plt.axis('off')
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Specify the path to the image file
image_path = r"C:\Users\ramco\OneDrive\Desktop\Mtech Docs\Second Sem\Image and Video\PG_lab\Photo1.jpg"

# Load the image in BGR format (OpenCV default)
image_bgr = cv2.imread(image_path)

# Check if the image was loaded successfully
if image_bgr is None:
    raise ValueError("Image not loaded. Check the file path and format.")

# Convert the BGR image to RGB format
image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)

# Convert RGB to YCrCb
image_ycrcb = cv2.cvtColor(image_rgb, cv2.COLOR_RGB2YCrCb)

# Simulate CMYK conversion
image_rgb_normalized = image_rgb / 255.0
K = 1 - np.max(image_rgb_normalized, axis=2)
C = (1 - image_rgb_normalized[..., 0] - K) / (1 - K + 1e-8)
M = (1 - image_rgb_normalized[..., 1] - K) / (1 - K + 1e-8)
Y = (1 - image_rgb_normalized[..., 2] - K) / (1 - K + 1e-8)

image_cmyk = np.dstack((C, M, Y, K)) * 255  # Convert back to range [0, 255]

# Convert CMYK image to uint8
image_cmyk = image_cmyk.astype(np.uint8)

# Save the YCrCb image
ycrcb_image_path = r"C:\Users\ramco\OneDrive\Desktop\Mtech Docs\Second Sem\Image and Video\PG_lab\Photo_YCrCb.jpg"
cv2.imwrite(ycrcb_image_path, image_ycrcb)

# Save the CMYK image (save individual channels as a 4-channel image)
cmyk_image_path = r"C:\Users\ramco\OneDrive\Desktop\Mtech Docs\Second Sem\Image and Video\PG_lab\Photo_CMYK.jpg"
cv2.imwrite(cmyk_image_path, image_cmyk)

# Display the images inline
plt.figure(figsize=(15, 10))

# Display the original RGB image
plt.subplot(1, 3, 1)
plt.imshow(image_rgb)
plt.title('Original RGB Image')
plt.axis('off')

# Display the YCrCb image
plt.subplot(1, 3, 2)
plt.imshow(image_ycrcb, cmap='gray')
plt.title('YCrCb Image')
plt.axis('off')

# Display the simulated CMYK image
# Since we can't display CMYK directly, we will display the individual channels
plt.subplot(1, 3, 3)
plt.imshow(image_cmyk)
plt.title('CMYK Image')
plt.axis('off')

plt.show()
